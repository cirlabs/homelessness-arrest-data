# %%
import glob
import os
import re

import numpy as np
import pandas as pd

# %% [markdown]
# ## Recent arrests by Continuum of Care
#
# Because full counts of unhoused people only happen every other year in many CoCs, and the counts only happen once a year, I will use an average of two years of data to analyze arrests and populations of unhoused people.

# %%
recent_arrests = pd.read_csv('../04_outputs/a01_aggregated_arrests_by_demographic.csv',
                             keep_default_na=False)

# %%
recent_arrests.loc[recent_arrests['_census_race'] ==
                   'Hispanic or Latino']
# Out:
#         _city _housing_status        _census_race  \
# 94   Portland          housed  Hispanic or Latino
# 101  Portland  no information  Hispanic or Latino
# 108  Portland        unhoused  Hispanic or Latino
# 115  Portland         unknown  Hispanic or Latino
#
#                     _census_ethnicity  arrests
# 94   Hispanic or Latino (of any race)     2669
# 101  Hispanic or Latino (of any race)      134
# 108  Hispanic or Latino (of any race)     1741
# 115  Hispanic or Latino (of any race)       92

# %% [markdown]
# For the purpose of analyzing demographics per U.S. Census data, "Hispanic or Latino" is orthogonal to race. For every arrest that specified it, I assign the data to ethnicty and mark race as unknown.

# %%
recent_arrests.loc[recent_arrests['_census_race'] ==
                   'Hispanic or Latino', '_census_race'] = 'Other/Unknown'

# %%
recent_arrests.loc[recent_arrests['_census_race']
                   == 'Unknown', '_census_race'] = 'Other/Unknown'

# %%
recent_arrests['_census_race'].unique()
# Out:
# array(['American Indian and Alaska Native', 'Asian',
#        'Black or African American',
#        'Native Hawaiian and Other Pacific Islander', 'Other/Unknown',
#        'White'], dtype=object)

# %%
recent_arrests['CoC Number'] = recent_arrests['_city'].replace({'Sacramento': 'CA-503',
                                                                'Los Angeles': 'CA-600',
                                                                'Oakland': 'CA-502',
                                                                'San Diego': 'CA-601',
                                                                'Portland': 'OR-501',
                                                                'Seattle': 'WA-500'
                                                                })

# %% [markdown]
# ### By Continuum of Care alone

# %%
recent_arrests_by_coc = (
    recent_arrests.groupby(
        [
            'CoC Number',
        ],
        dropna=False,
    ).agg(arrests_coc_total=('arrests', sum))
    .reset_index()
)

# %% [markdown]
# ### By CoC and housing status

# %%
recent_arrests_by_housing = (
    recent_arrests.groupby(
        [
            'CoC Number',
            '_housing_status'
        ],
        dropna=False,
    ).agg(arrests_by_housing=('arrests', sum))
    .reset_index()
)

# %% [markdown]
# ### By housing status and demographic

# %% [markdown]
# #### Race

# %%
recent_arrests.columns
# Out:
# Index(['_city', '_housing_status', '_census_race', '_census_ethnicity',
#        'arrests', 'CoC Number'],
#       dtype='object')

# %%
recent_arrests_by_housing_and_race = (
    recent_arrests.groupby(
        [
            'CoC Number',
            '_housing_status',
            '_census_race'
        ],
        dropna=False,
    ).agg(arrests=('arrests', sum))
    .reset_index()
)

# %% [markdown]
# ##### Issues with race and ethnicity
#
# Both the US Census Bureau and HUD differentiate between race and ethnicity with respect to Latino people. However, most arrest data has one field for 'race' where they specify that an arresteee was "Hispanic" or "Latino."
#
# Another complication is that HUD data does not provide a race x ethnicity demographic group, but rather separate aggregates for each. Because many "White" unhoused people may be Latino, I produce an additional "White alone" category duplicating data under "White" for comparison with census data, which provides a more conservative estimate of racial disparities in both homelessness and arrests.
#
# **Example**
#
# This is a toy example, but the proportions actually closely match those of 2019 San Diego data.
#
# | Variable        | Count | `White` population | `White alone` population |
# |:----------------|-------|--------------------|--------------------------|
# | arrests         |    25 |                700 |                      450 |
# | unhoused people |    16 |                700 |                      450 |

# %% [markdown]
# Using `White alone` as the estimate for rate comparisons provides a more conservative analysis of racial disparities in arrests.
#
#
# | rate / 100 people       | `White` population | `White alone` population |
# |:------------------------|--------------------|--------------------------|
# | arrests                 |                  4 |                        6 |
# | unhoused people         |                  2 |                        4 |

# %% [markdown]
# This is unnecessary because I already segmented out white and white alone.

# %%
recent_arrests_by_housing_and_race['_census_race'].unique()
# Out:
# array(['American Indian and Alaska Native', 'Asian',
#        'Black or African American',
#        'Native Hawaiian and Other Pacific Islander', 'Other/Unknown',
#        'White'], dtype=object)

# %%
recent_arrests_by_housing_and_race[
    'PITC Demographic'
] = recent_arrests_by_housing_and_race['_census_race'].str.replace(' and ', ' or ')

# %%
recent_arrests_by_housing_and_race.rename(
    columns={'_census_race': 'ACS Demographic'}, inplace=True)

# %%
white_alone_recent_arrests_by_housing_and_race = (
    recent_arrests[
        (recent_arrests['_census_race'] == 'White')
        & (recent_arrests['_census_ethnicity'] == 'Not Hispanic or Latino')
    ]
    .groupby(
        ['CoC Number', '_housing_status', '_census_race'],
        dropna=False,
    )
    .agg(arrests=('arrests', sum))
    .reset_index()
)

# %%
white_alone_recent_arrests_by_housing_and_race['ACS Demographic'] = 'Non-Hispanic White'
white_alone_recent_arrests_by_housing_and_race['PITC Demographic'] = 'White'

# %%
white_alone_recent_arrests_by_housing_and_race
# Out:
#    CoC Number _housing_status _census_race  arrests     ACS Demographic  \
# 0      CA-502          housed        White     1918  Non-Hispanic White
# 1      CA-502  no information        White       41  Non-Hispanic White
# 2      CA-502        unhoused        White      149  Non-Hispanic White
# 3      CA-502         unknown        White       18  Non-Hispanic White
# 4      CA-503          housed        White     6355  Non-Hispanic White
# 5      CA-503  no information        White       26  Non-Hispanic White
# 6      CA-503        unhoused        White     6348  Non-Hispanic White
# 7      CA-503         unknown        White       16  Non-Hispanic White
# 8      CA-600          housed        White    22060  Non-Hispanic White
# 9      CA-600  no information        White       13  Non-Hispanic White
# 10     CA-600        unhoused        White    13031  Non-Hispanic White
# 11     CA-600         unknown        White        1  Non-Hispanic White
# 12     CA-601          housed        White    14015  Non-Hispanic White
# 13     CA-601  no information        White    12690  Non-Hispanic White
# 14     CA-601        unhoused        White     4103  Non-Hispanic White
# 15     CA-601         unknown        White      304  Non-Hispanic White
# 16     OR-501          housed        White    18871  Non-Hispanic White
# 17     OR-501  no information        White      932  Non-Hispanic White
# 18     OR-501        unhoused        White    23334  Non-Hispanic White
# 19     OR-501         unknown        White      526  Non-Hispanic White
#
#    PITC Demographic
# 0             White
# 1             White
# 2             White
# 3             White
# 4             White
# 5             White
# 6             White
# 7             White
# 8             White
# 9             White
# 10            White
# 11            White
# 12            White
# 13            White
# 14            White
# 15            White
# 16            White
# 17            White
# 18            White
# 19            White

# %%
final_recent_arrests_by_housing_and_race = pd.concat(
    [white_alone_recent_arrests_by_housing_and_race, recent_arrests_by_housing_and_race])

# %%
final_recent_arrests_by_housing_and_race.drop(
    labels=['_census_race'], axis=1, inplace=True)

# %%
final_recent_arrests_by_housing_and_race.sort_values(
    by=['CoC Number', '_housing_status', 'PITC Demographic', 'ACS Demographic'],
    inplace=True,
    ignore_index=True,
)

# %%
final_recent_arrests_by_housing_and_race[final_recent_arrests_by_housing_and_race['PITC Demographic'] == 'White']
# Out:
#     CoC Number _housing_status  arrests     ACS Demographic PITC Demographic
# 5       CA-502          housed     1918  Non-Hispanic White            White
# 6       CA-502          housed     2192               White            White
# 12      CA-502  no information       41  Non-Hispanic White            White
# 13      CA-502  no information       46               White            White
# 19      CA-502        unhoused      149  Non-Hispanic White            White
# 20      CA-502        unhoused      187               White            White
# 26      CA-502         unknown       18  Non-Hispanic White            White
# 27      CA-502         unknown       23               White            White
# 33      CA-503          housed     6355  Non-Hispanic White            White
# 34      CA-503          housed    12399               White            White
# 37      CA-503  no information       26  Non-Hispanic White            White
# 38      CA-503  no information       32               White            White
# 44      CA-503        unhoused     6348  Non-Hispanic White            White
# 45      CA-503        unhoused     9222               White            White
# 49      CA-503         unknown       16  Non-Hispanic White            White
# 50      CA-503         unknown       19               White            White
# 56      CA-600          housed    22060  Non-Hispanic White            White
# 57      CA-600          housed    22067               White            White
# 61      CA-600  no information       13  Non-Hispanic White            White
# 62      CA-600  no information       13               White            White
# 68      CA-600        unhoused    13031  Non-Hispanic White            White
# 69      CA-600        unhoused    13036               White            White
# 71      CA-600         unknown        1  Non-Hispanic White            White
# 72      CA-600         unknown        1               White            White
# 77      CA-601          housed    14015  Non-Hispanic White            White
# 78      CA-601          housed    14016               White            White
# 83      CA-601  no information    12690  Non-Hispanic White            White
# 84      CA-601  no information    12690               White            White
# 89      CA-601        unhoused     4103  Non-Hispanic White            White
# 90      CA-601        unhoused     4103               White            White
# 95      CA-601         unknown      304  Non-Hispanic White            White
# 96      CA-601         unknown      304               White            White
# 102     OR-501          housed    18871  Non-Hispanic White            White
# 103     OR-501          housed    18871               White            White
# 109     OR-501  no information      932  Non-Hispanic White            White
# 110     OR-501  no information      932               White            White
# 116     OR-501        unhoused    23334  Non-Hispanic White            White
# 117     OR-501        unhoused    23334               White            White
# 123     OR-501         unknown      526  Non-Hispanic White            White
# 124     OR-501         unknown      526               White            White

# %% [markdown]
# #### Ethnicity

# %%
final_recent_arrests_by_housing_and_ethn = (
    recent_arrests.groupby(
        [
            'CoC Number',
            '_housing_status',
            '_census_ethnicity',
        ],
        dropna=False,
    ).agg(arrests=('arrests', sum))
    .reset_index()
)

# %%
final_recent_arrests_by_housing_and_ethn.rename(
    columns={'_census_ethnicity': 'ACS Demographic'}, inplace=True)

# %%
final_recent_arrests_by_housing_and_ethn[
    'PITC Demographic'
] = final_recent_arrests_by_housing_and_ethn['ACS Demographic'].replace(
    {
        'Not Hispanic or Latino': 'Non-Hispanic/Non-Latino',
        'Hispanic or Latino (of any race)': 'Hispanic/Latino',
    }
)

# %%
final_recent_arrests_by_housing_and_ethn
# Out:
#    CoC Number _housing_status                   ACS Demographic  arrests  \
# 0      CA-502          housed  Hispanic or Latino (of any race)     5692
# 1      CA-502          housed            Not Hispanic or Latino    15365
# 2      CA-502          housed                           Unknown     1335
# 3      CA-502  no information  Hispanic or Latino (of any race)       81
# 4      CA-502  no information            Not Hispanic or Latino      354
# 5      CA-502  no information                           Unknown       23
# 6      CA-502        unhoused  Hispanic or Latino (of any race)      322
# 7      CA-502        unhoused            Not Hispanic or Latino     1175
# 8      CA-502        unhoused                           Unknown      156
# 9      CA-502         unknown  Hispanic or Latino (of any race)       60
# 10     CA-502         unknown            Not Hispanic or Latino      198
# 11     CA-502         unknown                           Unknown       20
# 12     CA-503          housed  Hispanic or Latino (of any race)     6049
# 13     CA-503          housed            Not Hispanic or Latino    18019
# 14     CA-503          housed                           Unknown      270
# 15     CA-503  no information  Hispanic or Latino (of any race)        6
# 16     CA-503  no information            Not Hispanic or Latino       54
# 17     CA-503  no information                           Unknown        5
# 18     CA-503        unhoused  Hispanic or Latino (of any race)     2877
# 19     CA-503        unhoused            Not Hispanic or Latino    14918
# 20     CA-503        unhoused                           Unknown       57
# 21     CA-503         unknown  Hispanic or Latino (of any race)        3
# 22     CA-503         unknown            Not Hispanic or Latino       40
# 23     CA-600          housed  Hispanic or Latino (of any race)    92027
# 24     CA-600          housed            Not Hispanic or Latino    82886
# 25     CA-600          housed                           Unknown        2
# 26     CA-600  no information  Hispanic or Latino (of any race)       43
# 27     CA-600  no information            Not Hispanic or Latino       46
# 28     CA-600  no information                           Unknown        1
# 29     CA-600        unhoused  Hispanic or Latino (of any race)    21238
# 30     CA-600        unhoused            Not Hispanic or Latino    33764
# 31     CA-600        unhoused                           Unknown        1
# 32     CA-600         unknown  Hispanic or Latino (of any race)        6
# 33     CA-600         unknown            Not Hispanic or Latino        2
# 34     CA-601          housed  Hispanic or Latino (of any race)    14250
# 35     CA-601          housed            Not Hispanic or Latino    26213
# 36     CA-601  no information  Hispanic or Latino (of any race)     6628
# 37     CA-601  no information            Not Hispanic or Latino    21426
# 38     CA-601        unhoused  Hispanic or Latino (of any race)     1605
# 39     CA-601        unhoused            Not Hispanic or Latino     6816
# 40     CA-601         unknown  Hispanic or Latino (of any race)      163
# 41     CA-601         unknown            Not Hispanic or Latino      593
# 42     OR-501          housed  Hispanic or Latino (of any race)     2669
# 43     OR-501          housed            Not Hispanic or Latino    28087
# 44     OR-501          housed                           Unknown      195
# 45     OR-501  no information  Hispanic or Latino (of any race)      134
# 46     OR-501  no information            Not Hispanic or Latino     1397
# 47     OR-501  no information                           Unknown        9
# 48     OR-501        unhoused  Hispanic or Latino (of any race)     1741
# 49     OR-501        unhoused            Not Hispanic or Latino    31772
# 50     OR-501        unhoused                           Unknown       86
# 51     OR-501         unknown  Hispanic or Latino (of any race)       92
# 52     OR-501         unknown            Not Hispanic or Latino      825
# 53     OR-501         unknown                           Unknown        5
#
#            PITC Demographic
# 0           Hispanic/Latino
# 1   Non-Hispanic/Non-Latino
# 2                   Unknown
# 3           Hispanic/Latino
# 4   Non-Hispanic/Non-Latino
# 5                   Unknown
# 6           Hispanic/Latino
# 7   Non-Hispanic/Non-Latino
# 8                   Unknown
# 9           Hispanic/Latino
# 10  Non-Hispanic/Non-Latino
# 11                  Unknown
# 12          Hispanic/Latino
# 13  Non-Hispanic/Non-Latino
# 14                  Unknown
# 15          Hispanic/Latino
# 16  Non-Hispanic/Non-Latino
# 17                  Unknown
# 18          Hispanic/Latino
# 19  Non-Hispanic/Non-Latino
# 20                  Unknown
# 21          Hispanic/Latino
# 22  Non-Hispanic/Non-Latino
# 23          Hispanic/Latino
# 24  Non-Hispanic/Non-Latino
# 25                  Unknown
# 26          Hispanic/Latino
# 27  Non-Hispanic/Non-Latino
# 28                  Unknown
# 29          Hispanic/Latino
# 30  Non-Hispanic/Non-Latino
# 31                  Unknown
# 32          Hispanic/Latino
# 33  Non-Hispanic/Non-Latino
# 34          Hispanic/Latino
# 35  Non-Hispanic/Non-Latino
# 36          Hispanic/Latino
# 37  Non-Hispanic/Non-Latino
# 38          Hispanic/Latino
# 39  Non-Hispanic/Non-Latino
# 40          Hispanic/Latino
# 41  Non-Hispanic/Non-Latino
# 42          Hispanic/Latino
# 43  Non-Hispanic/Non-Latino
# 44                  Unknown
# 45          Hispanic/Latino
# 46  Non-Hispanic/Non-Latino
# 47                  Unknown
# 48          Hispanic/Latino
# 49  Non-Hispanic/Non-Latino
# 50                  Unknown
# 51          Hispanic/Latino
# 52  Non-Hispanic/Non-Latino
# 53                  Unknown

# %% [markdown]
# ### By demographic alone

# %% [markdown]
# #### Race

# %%
recent_arrests
# Out:
#            _city _housing_status                                _census_race  \
# 0    Los Angeles          housed           American Indian and Alaska Native
# 1    Los Angeles          housed                                       Asian
# 2    Los Angeles          housed                   Black or African American
# 3    Los Angeles          housed                   Black or African American
# 4    Los Angeles          housed  Native Hawaiian and Other Pacific Islander
# ..           ...             ...                                         ...
# 170    San Diego         unknown                   Black or African American
# 171    San Diego         unknown  Native Hawaiian and Other Pacific Islander
# 172    San Diego         unknown                               Other/Unknown
# 173    San Diego         unknown                               Other/Unknown
# 174    San Diego         unknown                                       White
#
#                     _census_ethnicity  arrests CoC Number
# 0              Not Hispanic or Latino       17     CA-600
# 1              Not Hispanic or Latino      254     CA-600
# 2    Hispanic or Latino (of any race)        4     CA-600
# 3              Not Hispanic or Latino    51045     CA-600
# 4              Not Hispanic or Latino       21     CA-600
# ..                                ...      ...        ...
# 170            Not Hispanic or Latino      261     CA-601
# 171            Not Hispanic or Latino        4     CA-601
# 172  Hispanic or Latino (of any race)      163     CA-601
# 173            Not Hispanic or Latino        8     CA-601
# 174            Not Hispanic or Latino      304     CA-601
#
# [175 rows x 6 columns]

# %%
recent_arrests_by_race = (
    recent_arrests.groupby(['CoC Number', '_census_race'], dropna=False)
    .agg(arrests_demographic=('arrests', sum))
    .reset_index()
)

# %%
recent_arrests_by_race_and_ethnicity = (
    recent_arrests.groupby(
        ['CoC Number', '_census_race', '_census_ethnicity'], dropna=False)
    .agg(arrests_demographic=('arrests', sum))
    .reset_index()
)

# %%
white_alone_recent_arrests_by_race = recent_arrests_by_race_and_ethnicity[
    (recent_arrests_by_race_and_ethnicity['_census_race'] == 'White') & (
        recent_arrests_by_race_and_ethnicity['_census_ethnicity'] == 'Not Hispanic or Latino')
].copy()

# %%
white_alone_recent_arrests_by_race
# Out:
#    CoC Number _census_race       _census_ethnicity  arrests_demographic
# 16     CA-502        White  Not Hispanic or Latino                 2126
# 28     CA-503        White  Not Hispanic or Latino                12745
# 38     CA-600        White  Not Hispanic or Latino                35105
# 45     CA-601        White  Not Hispanic or Latino                31112
# 52     OR-501        White  Not Hispanic or Latino                43663

# %%
white_alone_recent_arrests_by_race['_census_race'] = 'Non-Hispanic White'

# %%
final_recent_arrests_by_race = pd.concat(
    [white_alone_recent_arrests_by_race, recent_arrests_by_race], ignore_index=True)

# %%
final_recent_arrests_by_race.rename(
    columns={'_census_race': 'ACS Demographic'}, inplace=True)

# %%
final_recent_arrests_by_race['ACS Demographic'].unique()
# Out:
# array(['Non-Hispanic White', 'American Indian and Alaska Native', 'Asian',
#        'Black or African American',
#        'Native Hawaiian and Other Pacific Islander', 'Other/Unknown',
#        'White'], dtype=object)

# %%
acs_to_pitc = {
    'Non-Hispanic White': 'White',
    'American Indian and Alaska Native': 'American Indian or Alaska Native',
    'Native Hawaiian and Other Pacific Islander': 'Native Hawaiian or Other Pacific Islander',
}

# %%
final_recent_arrests_by_race['PITC Demographic'] = final_recent_arrests_by_race['ACS Demographic'].replace(
    acs_to_pitc)

# %%
final_recent_arrests_by_race.drop(
    labels=['_census_ethnicity'], axis=1, inplace=True)

# %%
final_recent_arrests_by_race
# Out:
#    CoC Number                             ACS Demographic  \
# 0      CA-502                          Non-Hispanic White
# 1      CA-503                          Non-Hispanic White
# 2      CA-600                          Non-Hispanic White
# 3      CA-601                          Non-Hispanic White
# 4      OR-501                          Non-Hispanic White
# 5      CA-502           American Indian and Alaska Native
# 6      CA-502                                       Asian
# 7      CA-502                   Black or African American
# 8      CA-502  Native Hawaiian and Other Pacific Islander
# 9      CA-502                               Other/Unknown
# 10     CA-502                                       White
# 11     CA-503           American Indian and Alaska Native
# 12     CA-503                                       Asian
# 13     CA-503                   Black or African American
# 14     CA-503  Native Hawaiian and Other Pacific Islander
# 15     CA-503                               Other/Unknown
# 16     CA-503                                       White
# 17     CA-600           American Indian and Alaska Native
# 18     CA-600                                       Asian
# 19     CA-600                   Black or African American
# 20     CA-600  Native Hawaiian and Other Pacific Islander
# 21     CA-600                               Other/Unknown
# 22     CA-600                                       White
# 23     CA-601                                       Asian
# 24     CA-601                   Black or African American
# 25     CA-601  Native Hawaiian and Other Pacific Islander
# 26     CA-601                               Other/Unknown
# 27     CA-601                                       White
# 28     OR-501           American Indian and Alaska Native
# 29     OR-501                                       Asian
# 30     OR-501                   Black or African American
# 31     OR-501  Native Hawaiian and Other Pacific Islander
# 32     OR-501                               Other/Unknown
# 33     OR-501                                       White
#
#     arrests_demographic                           PITC Demographic
# 0                  2126                                      White
# 1                 12745                                      White
# 2                 35105                                      White
# 3                 31112                                      White
# 4                 43663                                      White
# 5                    67           American Indian or Alaska Native
# 6                  1137                                      Asian
# 7                 14510                  Black or African American
# 8                   347  Native Hawaiian or Other Pacific Islander
# 9                  6272                              Other/Unknown
# 10                 2448                                      White
# 11                  213           American Indian or Alaska Native
# 12                 2173                                      Asian
# 13                17390                  Black or African American
# 14                  418  Native Hawaiian or Other Pacific Islander
# 15                  432                              Other/Unknown
# 16                21672                                      White
# 17                   22           American Indian or Alaska Native
# 18                  302                                      Asian
# 19                69979                  Black or African American
# 20                   31  Native Hawaiian or Other Pacific Islander
# 21               124565                              Other/Unknown
# 22                35117                                      White
# 23                 3047                                      Asian
# 24                19334                  Black or African American
# 25                  517  Native Hawaiian or Other Pacific Islander
# 26                23683                              Other/Unknown
# 27                31113                                      White
# 28                 1321           American Indian or Alaska Native
# 29                 1449                                      Asian
# 30                15325                  Black or African American
# 31                  323  Native Hawaiian or Other Pacific Islander
# 32                 4931                              Other/Unknown
# 33                43663                                      White

# %% [markdown]
# #### Ethnicity

# %%
final_recent_arrests_by_ethn = (
    recent_arrests.groupby(['CoC Number', '_census_ethnicity'], dropna=False)
    .agg(arrests_demographic=('arrests', sum))
    .reset_index()
)

# %%
final_recent_arrests_by_ethn.rename(
    columns={'_census_ethnicity': 'ACS Demographic'}, inplace=True)

# %%
final_recent_arrests_by_housing_and_ethn[
    'PITC Demographic'
] = final_recent_arrests_by_housing_and_ethn['ACS Demographic'].replace(
    {
        'Not Hispanic or Latino': 'Non-Hispanic/Non-Latino',
        'Hispanic or Latino (of any race)': 'Hispanic/Latino',
    }
)

# %%
final_recent_arrests_by_ethn['PITC Demographic'] = final_recent_arrests_by_ethn['ACS Demographic'].replace(
    {
        'Not Hispanic or Latino': 'Non-Hispanic/Non-Latino',
        'Hispanic or Latino (of any race)': 'Hispanic/Latino',
    }
)

# %% [markdown]
# ### Merging

# %% [markdown]
# #### Race and race by housing

# %%
final_recent_arrests_by_race
# Out:
#    CoC Number                             ACS Demographic  \
# 0      CA-502                          Non-Hispanic White
# 1      CA-503                          Non-Hispanic White
# 2      CA-600                          Non-Hispanic White
# 3      CA-601                          Non-Hispanic White
# 4      OR-501                          Non-Hispanic White
# 5      CA-502           American Indian and Alaska Native
# 6      CA-502                                       Asian
# 7      CA-502                   Black or African American
# 8      CA-502  Native Hawaiian and Other Pacific Islander
# 9      CA-502                               Other/Unknown
# 10     CA-502                                       White
# 11     CA-503           American Indian and Alaska Native
# 12     CA-503                                       Asian
# 13     CA-503                   Black or African American
# 14     CA-503  Native Hawaiian and Other Pacific Islander
# 15     CA-503                               Other/Unknown
# 16     CA-503                                       White
# 17     CA-600           American Indian and Alaska Native
# 18     CA-600                                       Asian
# 19     CA-600                   Black or African American
# 20     CA-600  Native Hawaiian and Other Pacific Islander
# 21     CA-600                               Other/Unknown
# 22     CA-600                                       White
# 23     CA-601                                       Asian
# 24     CA-601                   Black or African American
# 25     CA-601  Native Hawaiian and Other Pacific Islander
# 26     CA-601                               Other/Unknown
# 27     CA-601                                       White
# 28     OR-501           American Indian and Alaska Native
# 29     OR-501                                       Asian
# 30     OR-501                   Black or African American
# 31     OR-501  Native Hawaiian and Other Pacific Islander
# 32     OR-501                               Other/Unknown
# 33     OR-501                                       White
#
#     arrests_demographic                           PITC Demographic
# 0                  2126                                      White
# 1                 12745                                      White
# 2                 35105                                      White
# 3                 31112                                      White
# 4                 43663                                      White
# 5                    67           American Indian or Alaska Native
# 6                  1137                                      Asian
# 7                 14510                  Black or African American
# 8                   347  Native Hawaiian or Other Pacific Islander
# 9                  6272                              Other/Unknown
# 10                 2448                                      White
# 11                  213           American Indian or Alaska Native
# 12                 2173                                      Asian
# 13                17390                  Black or African American
# 14                  418  Native Hawaiian or Other Pacific Islander
# 15                  432                              Other/Unknown
# 16                21672                                      White
# 17                   22           American Indian or Alaska Native
# 18                  302                                      Asian
# 19                69979                  Black or African American
# 20                   31  Native Hawaiian or Other Pacific Islander
# 21               124565                              Other/Unknown
# 22                35117                                      White
# 23                 3047                                      Asian
# 24                19334                  Black or African American
# 25                  517  Native Hawaiian or Other Pacific Islander
# 26                23683                              Other/Unknown
# 27                31113                                      White
# 28                 1321           American Indian or Alaska Native
# 29                 1449                                      Asian
# 30                15325                  Black or African American
# 31                  323  Native Hawaiian or Other Pacific Islander
# 32                 4931                              Other/Unknown
# 33                43663                                      White

# %%
race_df = pd.merge(final_recent_arrests_by_race, final_recent_arrests_by_housing_and_race,
                   on=['CoC Number', 'ACS Demographic', 'PITC Demographic'])

# %%
race_df
# Out:
#     CoC Number     ACS Demographic  arrests_demographic PITC Demographic  \
# 0       CA-502  Non-Hispanic White                 2126            White
# 1       CA-502  Non-Hispanic White                 2126            White
# 2       CA-502  Non-Hispanic White                 2126            White
# 3       CA-502  Non-Hispanic White                 2126            White
# 4       CA-503  Non-Hispanic White                12745            White
# ..         ...                 ...                  ...              ...
# 120     OR-501       Other/Unknown                 4931    Other/Unknown
# 121     OR-501               White                43663            White
# 122     OR-501               White                43663            White
# 123     OR-501               White                43663            White
# 124     OR-501               White                43663            White
#
#     _housing_status  arrests
# 0            housed     1918
# 1    no information       41
# 2          unhoused      149
# 3           unknown       18
# 4            housed     6355
# ..              ...      ...
# 120         unknown       97
# 121          housed    18871
# 122  no information      932
# 123        unhoused    23334
# 124         unknown      526
#
# [125 rows x 6 columns]

# %% [markdown]
# #### Race, race by housing, housing

# %%
race_housing_df = pd.merge(race_df, recent_arrests_by_housing, on=[
                           'CoC Number', '_housing_status'])

# %% [markdown]
# ##### Race, etc. by CoC recent

# %%
race_housing_coc_df = pd.merge(race_housing_df, recent_arrests_by_coc)

# %% [markdown]
# #### Ethnicity, ethnicity by housing

# %%
ethn_df = pd.merge(final_recent_arrests_by_ethn, final_recent_arrests_by_housing_and_ethn,
                   on=['CoC Number', 'ACS Demographic', 'PITC Demographic'])

# %% [markdown]
# #### Ethnicity, ethnicity by housing, housing

# %%
ethn_housing_df = pd.merge(ethn_df, recent_arrests_by_housing, on=[
                           'CoC Number', '_housing_status'])

# %% [markdown]
# ##### Ethnicity, etc. by CoC

# %%
ethn_housing_coc_df = pd.merge(ethn_housing_df, recent_arrests_by_coc)

# %%
ethn_housing_coc_df.head()
# Out:
#   CoC Number                   ACS Demographic  arrests_demographic  \
# 0     CA-502  Hispanic or Latino (of any race)                 6155
# 1     CA-502            Not Hispanic or Latino                17092
# 2     CA-502                           Unknown                 1534
# 3     CA-502  Hispanic or Latino (of any race)                 6155
# 4     CA-502            Not Hispanic or Latino                17092
#
#           PITC Demographic _housing_status  arrests  arrests_by_housing  \
# 0          Hispanic/Latino          housed     5692               22392
# 1  Non-Hispanic/Non-Latino          housed    15365               22392
# 2                  Unknown          housed     1335               22392
# 3          Hispanic/Latino  no information       81                 458
# 4  Non-Hispanic/Non-Latino  no information      354                 458
#
#    arrests_coc_total
# 0              24781
# 1              24781
# 2              24781
# 3              24781
# 4              24781

# %% [markdown]
# #### Ethnicity and race

# %%
final_recent_arrest_df = pd.concat([race_housing_coc_df, ethn_housing_coc_df])

# %%
final_recent_arrest_df
# Out:
#    CoC Number                             ACS Demographic  \
# 0      CA-502                          Non-Hispanic White
# 1      CA-502           American Indian and Alaska Native
# 2      CA-502                                       Asian
# 3      CA-502                   Black or African American
# 4      CA-502  Native Hawaiian and Other Pacific Islander
# ..        ...                                         ...
# 49     OR-501                      Not Hispanic or Latino
# 50     OR-501                                     Unknown
# 51     OR-501            Hispanic or Latino (of any race)
# 52     OR-501                      Not Hispanic or Latino
# 53     OR-501                                     Unknown
#
#     arrests_demographic                           PITC Demographic  \
# 0                  2126                                      White
# 1                    67           American Indian or Alaska Native
# 2                  1137                                      Asian
# 3                 14510                  Black or African American
# 4                   347  Native Hawaiian or Other Pacific Islander
# ..                  ...                                        ...
# 49                62081                    Non-Hispanic/Non-Latino
# 50                  295                                    Unknown
# 51                 4636                            Hispanic/Latino
# 52                62081                    Non-Hispanic/Non-Latino
# 53                  295                                    Unknown
#
#    _housing_status  arrests  arrests_by_housing  arrests_coc_total
# 0           housed     1918               22392              24781
# 1           housed       50               22392              24781
# 2           housed     1050               22392              24781
# 3           housed    12949               22392              24781
# 4           housed      331               22392              24781
# ..             ...      ...                 ...                ...
# 49        unhoused    31772               33599              67012
# 50        unhoused       86               33599              67012
# 51         unknown       92                 922              67012
# 52         unknown      825                 922              67012
# 53         unknown        5                 922              67012
#
# [179 rows x 8 columns]

# %% [markdown]
# ### Calculations

# %%
final_recent_arrest_df['housing_status_and_demographic_pct_of_all_arrests'] = (
    final_recent_arrest_df['arrests'] /
    final_recent_arrest_df['arrests_coc_total']
)

# %%
final_recent_arrest_df['demographic_pct_of_housing_status_arrests'] = (
    final_recent_arrest_df['arrests'] /
    final_recent_arrest_df['arrests_by_housing']
)

# %%
final_recent_arrest_df['demographic_pct_of_all_arrests'] = (
    final_recent_arrest_df['arrests_demographic'] /
    final_recent_arrest_df['arrests_coc_total']
)

# %%
final_recent_arrest_df['housing_status_pct_of_all_arrests'] = (
    final_recent_arrest_df['arrests_by_housing'] /
    final_recent_arrest_df['arrests_coc_total']
)

# %%
final_recent_arrest_df['housing_status_pct_of_demographic_arrests'] = (
    final_recent_arrest_df['arrests'] /
    final_recent_arrest_df['arrests_demographic']
)

# %%
final_recent_arrest_df[['ACS Demographic',
                        'PITC Demographic']].drop_duplicates()
# Out:
#                               ACS Demographic  \
# 0                          Non-Hispanic White
# 1           American Indian and Alaska Native
# 2                                       Asian
# 3                   Black or African American
# 4  Native Hawaiian and Other Pacific Islander
# 5                               Other/Unknown
# 6                                       White
# 0            Hispanic or Latino (of any race)
# 1                      Not Hispanic or Latino
# 2                                     Unknown
#
#                             PITC Demographic
# 0                                      White
# 1           American Indian or Alaska Native
# 2                                      Asian
# 3                  Black or African American
# 4  Native Hawaiian or Other Pacific Islander
# 5                              Other/Unknown
# 6                                      White
# 0                            Hispanic/Latino
# 1                    Non-Hispanic/Non-Latino
# 2                                    Unknown

# %% [markdown]
# Arrest data averaged over 2017 and 2019, because:
#
# - CoCs performed counts of unsheltered people (limited to odd years)
# - These are the years for which I have Portland data (limited to 2017-part of 2021)
# - CoCs recorded race and ethnicity (limited to 2015 on)

# %% [markdown]
# ## Point in time count and ACS data

# %%
pitc_acs = pd.read_csv(
    '../04_outputs/c02_acs_pitc.csv',
    dtype={'county_fips': str, 'ACS Year': str, 'PITC Year': str},
)

# %%
pitc_acs['ACS Year'].unique()
# Out:
# array(['2019'], dtype=object)

# %%
pitc_acs['variable']
# Out:
# 0      ethnicity
# 1      ethnicity
# 2      ethnicity
# 3      ethnicity
# 4      ethnicity
#          ...
# 139     one race
# 140     one race
# 141     one race
# 142     one race
# 143     one race
# Name: variable, Length: 144, dtype: object

# %%
pitc_acs_avg = (
    pitc_acs[
        (pitc_acs['PITC Year'].isin(['2017', '2019']))
        & (pitc_acs['CoC Number'] != 'WA-500')
    ]
    .groupby(
        ['CoC Number', 'CoC Name', 'PITC Demographic', 'ACS Demographic', ], dropna=False
    )[
        [
            'ACS Percent',
            'demographic pct of unsheltered',
            'demographic pct of all homeless',
        ]
    ]
    .mean()
    .reset_index()
)

# %% [markdown]
# ### Merge arrest and pitc/coc census data

# %%
arrest_and_pitc_df = pd.merge(final_recent_arrest_df, pitc_acs_avg)

# %%
arrest_and_pitc_df.rename(
    columns={'ACS Percent': 'ACS Percent, CoC (one race)'}, inplace=True)

# %% [markdown]
# ## City ACS data

# %%
city_acs_df = pd.read_csv(
    '../04_outputs/c01_USCB-ACS5Y-DP05-City.csv',
    dtype={'ACS Year': str},
)

# %%
city_acs_df[['variable', 'ACS Demographic']].drop_duplicates()
# Out:
#                         variable                             ACS Demographic
# 0                      ethnicity            Hispanic or Latino (of any race)
# 1                      ethnicity                      Not Hispanic or Latino
# 2   race alone or in combination           American Indian and Alaska Native
# 3   race alone or in combination                                       Asian
# 4   race alone or in combination                   Black or African American
# 5   race alone or in combination  Native Hawaiian and Other Pacific Islander
# 6   race alone or in combination                             Some other race
# 7   race alone or in combination                                       White
# 8   race alone or in combination                          Non-Hispanic White
# 9                       one race           American Indian and Alaska Native
# 10                      one race                                       Asian
# 11                      one race                   Black or African American
# 12                      one race  Native Hawaiian and Other Pacific Islander
# 13                      one race                                       White
# 14                      one race                          Non-Hispanic White

# %%
arrest_and_pitc_df.rename(
    columns={'ACS Percent': 'ACS Percent, CoC (one race)'}, inplace=True)

# %%
city_acs_df.rename(columns={
    'geography': 'city',
    'ACS Percent': 'ACS Percent, city'}, inplace=True)

# %%
city_acs_df['city'].unique()
# Out:
# array(['Los Angeles', 'Oakland', 'Portland', 'Sacramento', 'San Diego',
#        'Seattle'], dtype=object)

# %% [markdown]
# ## Annual arrests by city

# %%
coc_to_city_dict = {'CA-600': 'Los Angeles',
                    'CA-502': 'Oakland',
                    'OR-501': 'Portland',
                    'CA-503': 'Sacramento',
                    'CA-601': 'San Diego',
                    'WA-500': 'Seattle'}

# %%
# coc_to_geo_dict = {v: k for k, v in geo_to_coc_dict.items()}

# %% [markdown]
# ## Merging city census data with arrest data

# %%
arrest_and_pitc_df.head()
# Out:
#   CoC Number                    ACS Demographic  arrests_demographic  \
# 0     CA-502                 Non-Hispanic White                 2126
# 1     CA-502                 Non-Hispanic White                 2126
# 2     CA-502                 Non-Hispanic White                 2126
# 3     CA-502                 Non-Hispanic White                 2126
# 4     CA-502  American Indian and Alaska Native                   67
#
#                    PITC Demographic _housing_status  arrests  \
# 0                             White          housed     1918
# 1                             White  no information       41
# 2                             White        unhoused      149
# 3                             White         unknown       18
# 4  American Indian or Alaska Native          housed       50
#
#    arrests_by_housing  arrests_coc_total  \
# 0               22392              24781
# 1                 458              24781
# 2                1653              24781
# 3                 278              24781
# 4               22392              24781
#
#    housing_status_and_demographic_pct_of_all_arrests  \
# 0                                           0.077398
# 1                                           0.001654
# 2                                           0.006013
# 3                                           0.000726
# 4                                           0.002018
#
#    demographic_pct_of_housing_status_arrests  demographic_pct_of_all_arrests  \
# 0                                   0.085656                        0.085792
# 1                                   0.089520                        0.085792
# 2                                   0.090139                        0.085792
# 3                                   0.064748                        0.085792
# 4                                   0.002233                        0.002704
#
#    housing_status_pct_of_all_arrests  \
# 0                           0.903595
# 1                           0.018482
# 2                           0.066704
# 3                           0.011218
# 4                           0.903595
#
#    housing_status_pct_of_demographic_arrests  \
# 0                                   0.902164
# 1                                   0.019285
# 2                                   0.070085
# 3                                   0.008467
# 4                                   0.746269
#
#                                CoC Name  ACS Percent, CoC (one race)  \
# 0  Oakland, Berkeley/Alameda County CoC                        0.314
# 1  Oakland, Berkeley/Alameda County CoC                        0.314
# 2  Oakland, Berkeley/Alameda County CoC                        0.314
# 3  Oakland, Berkeley/Alameda County CoC                        0.314
# 4  Oakland, Berkeley/Alameda County CoC                        0.007
#
#    demographic pct of unsheltered  demographic pct of all homeless
# 0                        0.327639                         0.308711
# 1                        0.327639                         0.308711
# 2                        0.327639                         0.308711
# 3                        0.327639                         0.308711
# 4                        0.036514                         0.033684

# %%
city_acs_df.columns.intersection(arrest_and_pitc_df.columns)
# Out:
# Index(['ACS Demographic', 'CoC Number'], dtype='object')

# %%
final_df = pd.merge(
    arrest_and_pitc_df,
    city_acs_df[city_acs_df['variable'].isin(
        ['ethnicity', 'race alone or in combination'])],
    on=['CoC Number', 'ACS Demographic'],
    suffixes=(' CoC', ' city'),
)

# %%
final_df.loc[
    (final_df['city'] == 'Oakland')
    & (final_df['ACS Demographic'] == 'Black or African American'),
    'demographic pct of unsheltered, city',
] = np.nan

# %%
final_df.loc[
    (final_df['city'] == 'Oakland')
    & (final_df['ACS Demographic'] == 'Black or African American'),
    'demographic pct of all homeless, city',
] = 0.69

# %%
final_df.loc[
    (final_df['city'] == 'Oakland')
    & (final_df['ACS Demographic'] == 'American Indian and Alaska Native'),
    'demographic pct of all homeless, city',
] = 0.03

# %%
final_df.loc[
    (final_df['city'] == 'Oakland')
    & (final_df['ACS Demographic'] == 'Hispanic or Latino (of any race)'),
    'demographic pct of all homeless, city',
] = 0.13

# %% [markdown]
# [2019](https://www.documentcloud.org/documents/22029257-2019-los-angeles-continuum-of-care-homeless-count-methodology-report#document/p83/a2110003): 48.2%
#
# [2017](https://www.documentcloud.org/documents/22029256-2017-los-angeles-continuum-of-care-homeless-count-methodology-report#document/p75/a2110001): 56.9%

# %%
(.482+.569)/2
# Out:
# 0.5255

# %%
final_df.loc[
    (final_df['city'] == 'Los Angeles')
    & (final_df['ACS Demographic'] == 'Black or African American'),
    'demographic pct of all homeless, city',
] = 0.526

# %%
(.022+.031)/2
# Out:
# 0.0265

# %%
final_df.loc[
    (final_df['city'] == 'Los Angeles')
    & (final_df['ACS Demographic'] == 'American Indian and Alaska Native'),
    'demographic pct of all homeless, city',
] = 0.027

# %%
(0.348+.307)/2
# Out:
# 0.3275

# %%
final_df.loc[
    (final_df['city'] == 'Los Angeles')
    & (final_df['ACS Demographic'] == 'Hispanic or Latino (of any race)'),
    'demographic pct of all homeless, city',
] = 0.328

# %% [markdown]
# <a id="fc"></a>
# Fact-checking note: The percent of each city's Black population is always higher than the Black population of the county to which it belongs.

# %%
final_df[final_df['ACS Demographic'] == 'Black or African American'][
    [
        'ACS Demographic',
        'CoC Name',
        'ACS Percent, CoC (one race)',
        'ACS Percent, city',
        'demographic pct of all homeless',
        'demographic pct of all homeless, city',
    ]
].applymap(
    lambda x: round(x * 100) if isinstance(x, (float, np.floating)) else x,
    na_action='ignore',
).drop_duplicates()
# Out:
#               ACS Demographic                                CoC Name  \
# 12  Black or African American    Oakland, Berkeley/Alameda County CoC
# 33  Black or African American            Sacramento City & County CoC
# 53  Black or African American           Los Angeles City & County CoC
# 70  Black or African American           San Diego City and County CoC
# 94  Black or African American  Portland, Gresham/Multnomah County CoC
#
#     ACS Percent, CoC (one race)  ACS Percent, city  \
# 12                           11                 27
# 33                           10                 16
# 53                            7                 10
# 70                            5                  8
# 94                            6                  8
#
#     demographic pct of all homeless  demographic pct of all homeless, city
# 12                               48                                   69.0
# 33                               32                                    NaN
# 53                               47                                   53.0
# 70                               23                                    NaN
# 94                               14                                    NaN

# %%
final_df.to_csv('../04_outputs/a03_arrests_and_demographics.csv', index=False)
